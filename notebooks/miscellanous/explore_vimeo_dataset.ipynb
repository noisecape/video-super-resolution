# %%
from pathlib import Path
import os
import cv2
import matplotlib.pyplot as plt

# %%
first_sequence_parent_folder = Path('/home/noisecape/developer/video-super-resolution/data/datasets/vimeo90k/vimeo_septuplet/sequences/00001/0001')

# %%
imgs = os.listdir(first_sequence_parent_folder)

# %%
img = cv2.cvtColor(cv2.imread(first_sequence_parent_folder/imgs[0]), cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (256, 448, 3)
